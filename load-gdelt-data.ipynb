# %% [markdown]
# <a href="https://www.kaggle.com/chasset/load-gdelt-data?scriptVersionId=89093458" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # GDELT
#
# The GDELT [project](https://www.gdeltproject.org/) collects events in the whole world.
#
# All data are accessible via Google Bigquery. The project is hosted at [gdelt-bq](https://console.cloud.google.com/bigquery?project=gdelt-bq) and counts several databases.
#
# ## Inside gdeltv2 database
#
# It seems that the *gdeltv2* database hosts the major part of the project. Let us access the table names of this database:

# %%
from google.cloud import bigquery
client = bigquery.Client()
dataset_ref = client.dataset("gdeltv2", project="gdelt-bq")
dataset = client.get_dataset(dataset_ref)
tables = list(client.list_tables(dataset))
for table in tables:  
    print(table.table_id)
# Out:
# Using Kaggle's public dataset BigQuery integration.
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188         try:
# --> 189             return target()
#     190
#
# ~/.local/lib/python3.7/site-packages/kaggle_gcp.py in api_request(self, *args, **kwargs)
#      99         try:
# --> 100             return super().api_request(*args, **kwargs)
#     101         except Forbidden as e:
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout)
#     483         if not 200 <= response.status_code < 300:
# --> 484             raise exceptions.from_http_response(response)
#     485
#
# TooManyRequests: 429 GET https://dp.kaggle.net/bigquery/v2/projects/gdelt-bq/datasets/gdeltv2?prettyPrint=false: Quota exceeded
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# /tmp/ipykernel_34/4198143474.py in <module>
#       2 client = bigquery.Client()
#       3 dataset_ref = client.dataset("gdeltv2", project="gdelt-bq")
# ----> 4 dataset = client.get_dataset(dataset_ref)
#       5 tables = list(client.list_tables(dataset))
#       6 for table in tables:
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py in get_dataset(self, dataset_ref, retry, timeout)
#     671             method="GET",
#     672             path=path,
# --> 673             timeout=timeout,
#     674         )
#     675         return Dataset.from_api_repr(api_response)
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py in _call_api(self, retry, span_name, span_attributes, job_ref, **kwargs)
#     634                 name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     635             ):
# --> 636                 return call()
#     637         return call()
#     638
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     289                 sleep_generator,
#     290                 self._deadline,
# --> 291                 on_error=on_error,
#     292             )
#     293
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     209                         last_exc,
#     210                     ),
# --> 211                     last_exc,
#     212                 )
#     213             else:
#
# /opt/conda/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# RetryError: Deadline of 120.0s exceeded while calling target function, last exception: 429 GET https://dp.kaggle.net/bigquery/v2/projects/gdelt-bq/datasets/gdeltv2?prettyPrint=false: Quota exceeded

# %% [markdown]
# ## Inside events
#
# We will further explore the table [events](https://console.cloud.google.com/bigquery?project=gdelt-bq&d=gdeltv2&p=gdelt-bq&t=events&page=table&ws=!1m5!1m4!4m3!1sgdelt-bq!2sgdeltv2!3sevents) of the *gdeltv2* database.

# %%
query = """
        SELECT *
        FROM `gdelt-bq.gdeltv2.events`
        LIMIT 10
        """
query_job = client.query(query)
events = query_job.to_dataframe()
events

# %% [markdown]
# ## Inside the knowledge graph

# %%
query = """
        SELECT *
        FROM `gdelt-bq.gdeltv2.gkg`
        LIMIT 10
        """
query_job = client.query(query)
gkg = query_job.to_dataframe()
gkg
